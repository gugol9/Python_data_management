# %%
import pandas as pd
from datetime import datetime
from pytz import utc
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv("reviews_courses.csv" ,parse_dates=["Timestamp"])

# %%
print(type(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
data
# Out:
#                                       Course Name                 Timestamp  \
# 0              The Python Course: AI/ML in Python 2021-04-02 06:25:52+00:00
# 1              The Python Course: AI/ML in Python 2021-04-02 05:12:34+00:00
# 2              The Python Course: AI/ML in Python 2021-04-02 05:11:03+00:00
# 3              The Python Course: AI/ML in Python 2021-04-02 03:33:24+00:00
# 4              The Python Course: AI/ML in Python 2021-04-02 03:31:49+00:00
# ...                                           ...                       ...
# 44995  The Python Course: From Beginner to Expert 2018-01-01 01:11:26+00:00
# 44996          The Python Course: AI/ML in Python 2018-01-01 01:09:56+00:00
# 44997          The Python Course: AI/ML in Python 2018-01-01 01:08:11+00:00
# 44998  The Python Course: From Beginner to Expert 2018-01-01 01:05:26+00:00
# 44999          The Python Course: AI/ML in Python 2018-01-01 01:01:16+00:00
#
#        Rating Comment
# 0         4.0     NaN
# ...

# %%
data.head(12)

# %%
data.tail(10)

# %%
data["Course Name"].unique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 data["Course Name"].unique()
#
# NameError: name 'data' is not defined

# %%
data['Course Name'] == 'The Python Course: AI/ML in Python'
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 44995    False
# 44996     True
# 44997     True
# 44998    False
# 44999     True
# Name: Course Name, Length: 45000, dtype: bool

# %%
data[data['Course Name'] == 'The Python Course: AI/ML in Python']
# Out:
#                               Course Name                  Timestamp  Rating  \
# 0      The Python Course: AI/ML in Python  2021-04-02 06:25:52+00:00     4.0
# 1      The Python Course: AI/ML in Python  2021-04-02 05:12:34+00:00     4.0
# 2      The Python Course: AI/ML in Python  2021-04-02 05:11:03+00:00     4.0
# 3      The Python Course: AI/ML in Python  2021-04-02 03:33:24+00:00     5.0
# 4      The Python Course: AI/ML in Python  2021-04-02 03:31:49+00:00     4.5
# ...                                   ...                        ...     ...
# 44992  The Python Course: AI/ML in Python  2018-01-01 01:27:26+00:00     5.0
# 44994  The Python Course: AI/ML in Python  2018-01-01 01:19:24+00:00     5.0
# 44996  The Python Course: AI/ML in Python  2018-01-01 01:09:56+00:00     5.0
# 44997  The Python Course: AI/ML in Python  2018-01-01 01:08:11+00:00     5.0
# 44999  The Python Course: AI/ML in Python  2018-01-01 01:01:16+00:00     5.0
#
#       Comment
# 0         NaN
# ...

# %%
data[data['Course Name'] == 'The Python Course: AI/ML in Python']['Rating'].mean()
# Out:
# 4.477270180942244

# %%
data[data['Course Name'] == 'The Python Course: AI/ML in Python']['Rating'] >4
# Out:
# 0        False
# 1        False
# 2        False
# 3         True
# 4         True
#          ...
# 44992     True
# 44994     True
# 44996     True
# 44997     True
# 44999     True
# Name: Rating, Length: 35702, dtype: bool

# %%
data[data['Rating'] > 4]
# Out:
#                                       Course Name                  Timestamp  \
# 3              The Python Course: AI/ML in Python  2021-04-02 03:33:24+00:00
# 4              The Python Course: AI/ML in Python  2021-04-02 03:31:49+00:00
# 5              The Python Course: AI/ML in Python  2021-04-02 01:10:06+00:00
# 6              The Python Course: AI/ML in Python  2021-04-02 00:44:54+00:00
# 7              The Python Course: AI/ML in Python  2021-04-01 23:42:02+00:00
# ...                                           ...                        ...
# 44994          The Python Course: AI/ML in Python  2018-01-01 01:19:24+00:00
# 44996          The Python Course: AI/ML in Python  2018-01-01 01:09:56+00:00
# 44997          The Python Course: AI/ML in Python  2018-01-01 01:08:11+00:00
# 44998  The Python Course: From Beginner to Expert  2018-01-01 01:05:26+00:00
# 44999          The Python Course: AI/ML in Python  2018-01-01 01:01:16+00:00
#
#        Rating Comment
# ...

# %%
abc = data[data['Rating'] > 4]
.shape[0]
print('f' 'Kursow z ratingiem wiekszym niz 4: {abc})'
# Out:
#   Cell In[17], line 2
#     .shape[0]
#     ^
# SyntaxError: invalid syntax

# %%
data[
    (data['Rating'] > 4) &
    (data['Course Name'] == 'The Python Course: OpenCV in Python')
].head()
# Out:
#                              Course Name                  Timestamp  Rating  \
# 31   The Python Course: OpenCV in Python  2021-04-01 01:32:52+00:00     5.0
# 34   The Python Course: OpenCV in Python  2021-03-31 22:53:04+00:00     5.0
# 43   The Python Course: OpenCV in Python  2021-03-31 19:15:25+00:00     5.0
# 45   The Python Course: OpenCV in Python  2021-03-31 17:23:15+00:00     5.0
# 101  The Python Course: OpenCV in Python  2021-03-29 21:54:00+00:00     4.5
#
#     Comment
# 31      NaN
# 34      NaN
# 43      NaN
# 45      NaN
# 101     NaN

# %%
data[
    (data['Timestamp'] >= datetime(2020,7,1,tzinfo=utc))&
    (data['Timestamp'] <= datetime(2020,12,31,tzinfo=utc))
]
# Out:
#                                         Course Name                 Timestamp  \
# 3065  The Python Course: Interactive Visualizations 2020-12-30 23:28:34+00:00
# 3066             The Python Course: AI/ML in Python 2020-12-30 22:59:02+00:00
# 3067             The Python Course: AI/ML in Python 2020-12-30 22:40:10+00:00
# 3068             The Python Course: AI/ML in Python 2020-12-30 21:56:41+00:00
# 3069             The Python Course: AI/ML in Python 2020-12-30 21:14:34+00:00
# ...                                             ...                       ...
# 9729             The Python Course: AI/ML in Python 2020-07-01 03:09:44+00:00
# 9730             The Python Course: AI/ML in Python 2020-07-01 03:09:12+00:00
# 9731             The Python Course: AI/ML in Python 2020-07-01 02:40:58+00:00
# 9732             The Python Course: AI/ML in Python 2020-07-01 02:04:02+00:00
# 9733             The Python Course: AI/ML in Python 2020-07-01 00:01:34+00:00
#
# ...

# %%
data[
    (data['Timestamp'] >= datetime(2020,7,1,tzinfo=utc))&
    (data['Timestamp'] <= datetime(2020,12,31,tzinfo=utc))&
    (data['Course Name'] == 'The Python Course: From Beginner to Expert')
]
# Out:
#                                      Course Name                 Timestamp  \
# 3073  The Python Course: From Beginner to Expert 2020-12-30 19:30:23+00:00
# 3082  The Python Course: From Beginner to Expert 2020-12-30 16:07:10+00:00
# 3085  The Python Course: From Beginner to Expert 2020-12-30 14:51:37+00:00
# 3095  The Python Course: From Beginner to Expert 2020-12-30 05:30:11+00:00
# 3109  The Python Course: From Beginner to Expert 2020-12-29 17:51:48+00:00
# ...                                          ...                       ...
# 9625  The Python Course: From Beginner to Expert 2020-07-03 05:50:43+00:00
# 9658  The Python Course: From Beginner to Expert 2020-07-02 13:19:52+00:00
# 9695  The Python Course: From Beginner to Expert 2020-07-01 17:31:08+00:00
# 9705  The Python Course: From Beginner to Expert 2020-07-01 13:43:15+00:00
# 9707  The Python Course: From Beginner to Expert 2020-07-01 12:56:49+00:00
#
#       Rating Comment
# 3073     5.0     NaN
# 3082     4.0     NaN
# ...

# %%
data.groupby(['Timestamp']).mean()
# Out:
# /var/folders/w7/knnl1k6n76nf7vql7q_4b6zw0000gn/T/ipykernel_89856/3227589063.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby(['Timestamp']).mean()
#                            Rating
# Timestamp
# 2018-01-01 01:01:16+00:00     5.0
# 2018-01-01 01:05:26+00:00     5.0
# 2018-01-01 01:08:11+00:00     5.0
# 2018-01-01 01:09:56+00:00     5.0
# 2018-01-01 01:11:26+00:00     4.0
# ...                           ...
# 2021-04-02 03:31:49+00:00     4.5
# 2021-04-02 03:33:24+00:00     5.0
# 2021-04-02 05:11:03+00:00     4.0
# 2021-04-02 05:12:34+00:00     4.0
# 2021-04-02 06:25:52+00:00     4.0
#
# [44988 rows x 1 columns]

# %%
data['Timestamp'].dt.date
# Out:
# 0        2021-04-02
# 1        2021-04-02
# 2        2021-04-02
# 3        2021-04-02
# 4        2021-04-02
#             ...
# 44995    2018-01-01
# 44996    2018-01-01
# 44997    2018-01-01
# 44998    2018-01-01
# 44999    2018-01-01
# Name: Timestamp, Length: 45000, dtype: object

# %%
data['Day'] = data['Timestamp'].dt.date

# %%
now = datetime.now()
date = now.strftime("%Y-%m-%d")
print("Data:", date)
# Out:
# Data: 2023-04-15

# %%
data['Day'] = data['Timestamp'].dt.date

# %%
data.groupby(['Day']).mean()
# Out:
# /var/folders/w7/knnl1k6n76nf7vql7q_4b6zw0000gn/T/ipykernel_89856/2676410882.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby(['Day']).mean()
#               Rating
# Day
# 2018-01-01  4.532609
# 2018-01-02  4.122807
# 2018-01-03  4.360465
# 2018-01-04  4.531250
# 2018-01-05  4.423077
# ...              ...
# 2021-03-29  4.240000
# 2021-03-30  4.428571
# 2021-03-31  4.453125
# 2021-04-01  4.592593
# 2021-04-02  4.357143
#
# [1188 rows x 1 columns]

# %%
data.columns
# Out:
# Index(['Course Name', 'Timestamp', 'Rating', 'Comment', 'Day'], dtype='object')

# %%
plt.figure(figsize = (20,10))
plt.plot([1,2,3],[1,2,3])

# %%
dataDay.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 dataDay.columns
#
# NameError: name 'dataDay' is not defined
